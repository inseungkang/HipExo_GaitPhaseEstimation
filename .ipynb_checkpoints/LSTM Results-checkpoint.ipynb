# %% [markdown]
# ## Plot Results

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df_results = pd.read_csv('../Gait Phase Estimation Results/initial_window_sweep_results.csv', index_col=0)

# %%
display(df_results)
# Out:
#     window_size  lstm_units lstm_activation lstm_recurrent_regularizer  \
# 0            20          10            relu                         L2
# 1            40          10            relu                         L2
# 2            60          10            relu                         L2
# 3            80          10            relu                         L2
# 4           100          10            relu                         L2
# 5           120          10            relu                         L2
# 6           140          10            relu                         L2
# 7           160          10            relu                         L2
# 8           180          10            relu                         L2
# 9           200          10            relu                         L2
# 10          220          10            relu                         L2
#
#    lstm_kernel_regularizer dense_activation dense_kernel_regularizer  \
# 0                       L2             tanh                       L2
# 1                       L2             tanh                       L2
# 2                       L2             tanh                       L2
# 3                       L2             tanh                       L2
# 4                       L2             tanh                       L2
# 5                       L2             tanh                       L2
# 6                       L2             tanh                       L2
# 7                       L2             tanh                       L2
# 8                       L2             tanh                       L2
# 9                       L2             tanh                       L2
# 10                      L2             tanh                       L2
#
#              optim_loss optim_optimizer  left_rmse_mean  right_rmse_mean
# 0   mean_absolute_error            adam        2.359707         2.482339
# 1   mean_absolute_error            adam        2.192722         2.417346
# 2   mean_absolute_error            adam        2.244903         2.415497
# 3   mean_absolute_error            adam        2.231187         2.412414
# 4   mean_absolute_error            adam        7.374008         7.443652
# 5   mean_absolute_error            adam        2.655973         2.720643
# 6   mean_absolute_error            adam        4.954866         5.113672
# 7   mean_absolute_error            adam        2.349367         2.334448
# 8   mean_absolute_error            adam        4.509090         4.759624
# 9   mean_absolute_error            adam        4.930241         5.217481
# 10  mean_absolute_error            adam        3.313072         3.270962

# %%
plt.figure(1, figsize=[10,7.5])
plt.plot(df_results.window_size, df_results.left_rmse_mean)
plt.plot(df_results.window_size, df_results.right_rmse_mean)
plt.title('LSTM Error vs Window Size')
plt.xlabel('Window Size (datapoints)')
plt.ylabel('RMSE in Gait Phase')
plt.legend(['Left Leg', 'Right Leg'])
plt.show()

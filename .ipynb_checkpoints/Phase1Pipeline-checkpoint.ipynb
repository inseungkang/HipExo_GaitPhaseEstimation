# %% [markdown]
# ## Phase 1 Pipeline

# %% [markdown]
# #### Setup

# %%
from model_training import *
from data_processing import *
import pandas as pd
from numpy.random import seed
import tensorflow as tf

# %%
# Seed Random Number Generators for Reproducibility
seed(1)
tf.random.set_seed(seed=5)

# %% [markdown]
# #### Configure Hyperparameter Search Space

# %%
hyperparam_space = {
    'window_size': [40],
    'model': 'lstm',
    'lstm': {
      'units': [20],
      'activation': ['tanh']
    },
    'dense': {
        'activation': ['relu']
    },
    'optimizer': {
        'loss': ['mean_absolute_error'],
        'optimizer': ['adam']
    },
    'training': {
        'epochs': [2],
        'batch_size': [128]
    }
}

hyperparameter_configs = get_model_configs(hyperparam_space)

# %% [markdown]
# #### Load Data

# %%
data = import_data(5, 'CW_BT')
data = label_data(data)
data_list = cut_data(data)
# Out:
# data/AB05\CW_BT_1.npy
# data/AB05\CW_BT_2.npy
# data/AB05\CW_BT_3.npy
# data/AB05\CW_BT_4.npy
# data/AB05\CW_BT_5.npy

# %% [markdown]
# #### Train Models

# %%
trial_results, average_results = train_models(hyperparam_space['model'], hyperparameter_configs, data_list)

# %% [markdown]
# #### View Results

# %%
display(average_results)

# %%
display(trial_results)

# %% [markdown]
# #### Example Hyperparameter Search Space Configs

# %%
## LSTM Model
# hyperparam_space = {
#     'window_size': [20],
#     'model': 'lstm',
#     'lstm': {
#       'units': [30],
#       'activation': ['relu']
#     },
#     'dense': {
#         'activation': ['tanh']
#     },
#     'optimizer': {
#         'loss': ['mean_absolute_error'],
#         'optimizer': ['adam']
#     },
#     'training': {
#         'epochs': [10],
#         'batch_size': [128]
#     }
# }

## CNN Model
# hyperparam_space = {
#     'window_size': [20],
#     'model': 'cnn',
#     'cnn': {
#       'kernel_size': [10],
#       'activation': ['relu']
#     },
#     'dense': {
#         'activation': ['tanh']
#     },
#     'optimizer': {
#         'loss': ['mean_absolute_error'],
#         'optimizer': ['adam']
#     },
#     'training': {
#         'epochs': [10],
#         'batch_size': [128]
#     }
# }

## MLP Model
# hyperparam_space = {
#     'window_size': [20],
#     'model': 'mlp',
#     'dense': {
#         'num_layers': [10, 20],
#         'num_nodes': [5, 10],
#         'activation': ['tanh']
#     },
#     'optimizer': {
#         'loss': ['mean_absolute_error'],
#         'optimizer': ['adam']
#     },
#     'training': {
#         'epochs': [10],
#         'batch_size': [128]
#     }
# }
